# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# ## __1 - Business Problem__
# ___Prepare a classification model using SVM for salary data___

# %% [markdown]
# ## __2 - Data collection and description__

# %%
test_tmp = pd.read_csv(r"C:\Users\Rustham Sorab\Desktop\Data Science\17.SVM\Raw Data\SalaryData_Test.csv")
train_tmp = pd.read_csv(r"C:\Users\Rustham Sorab\Desktop\Data Science\17.SVM\Raw Data\SalaryData_Train.csv")

# %%
df_tmp = test_tmp.append(train_tmp)
# Out:
# C:\Users\Rustham Sorab\AppData\Local\Temp\ipykernel_3688\2035400017.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tmp = test_tmp.append(train_tmp)

# %%
test = test_tmp.copy()
train = train_tmp.copy()

# %%
test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
str_c = ["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
number = LabelEncoder()

# %%
for i in str_c:
    train[i]= number.fit_transform(train[i])
    test[i]=number.fit_transform(test[i])

# %%
test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          2          1            7              4           6
# 1   38          2         11            9              2           4
# 2   28          1          7           12              2          10
# 3   44          2         15           10              2           6
# 4   34          2          0            6              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            40      37
# 1             0     4    1            0            0            50      37
# 2             0     4    1            0            0            40      37
# 3             0     2    1         7688            0            40      37
# 4             1     4    1            0            0            30      37
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2    >50K
# 3    >50K
# 4   <=50K

# %%
train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
mapping = {' >50K': 1, ' <=50K': 2}

# %%
train = train.replace({'Salary': mapping})
test = test.replace({'Salary': mapping})

# %%
df = train.append(test)
# Out:
# C:\Users\Rustham Sorab\AppData\Local\Temp\ipykernel_3688\2767323617.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = train.append(test)

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
df1.shape
# Out:
# (45221, 14)

# %%
df1.describe().T
# Out:
#                  count         mean          std   min   25%   50%   75%  \
# age            45221.0    38.548086    13.217981  17.0  28.0  37.0  47.0
# workclass      45221.0     2.204507     0.958132   0.0   2.0   2.0   2.0
# education      45221.0    10.313217     3.816992   0.0   9.0  11.0  12.0
# educationno    45221.0    10.118463     2.552909   1.0   9.0  10.0  13.0
# maritalstatus  45221.0     2.585148     1.500460   0.0   2.0   2.0   4.0
# occupation     45221.0     5.969572     4.026444   0.0   2.0   6.0   9.0
# relationship   45221.0     1.412684     1.597242   0.0   0.0   1.0   3.0
# race           45221.0     3.680281     0.832361   0.0   4.0   4.0   4.0
# sex            45221.0     0.675062     0.468357   0.0   0.0   1.0   1.0
# capitalgain    45221.0  1101.454700  7506.511295   0.0   0.0   0.0   0.0
# capitalloss    45221.0    88.548617   404.838249   0.0   0.0   0.0   0.0
# hoursperweek   45221.0    40.938038    12.007640   1.0  40.0  40.0  45.0
# native         45221.0    35.431503     5.931380   0.0  37.0  37.0  37.0
# Salary         45221.0     1.752151     0.431769   1.0   2.0   2.0   2.0
#
#                    max
# age               90.0
# workclass          6.0
# education         15.0
# educationno       16.0
# maritalstatus      6.0
# occupation        13.0
# relationship       5.0
# race               4.0
# sex                1.0
# capitalgain    99999.0
# capitalloss     4356.0
# hoursperweek      99.0
# native            39.0
# Salary             2.0

# %%
df1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %% [markdown]
# ### Finding Correlation

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['educationno'].skew()))
print("Kurtosis: {}".format(df1['educationno'].kurtosis()))
ax = sns.kdeplot(df1['educationno'],fill=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()
# Out:
# Skew: -0.31062061074424
# Kurtosis: 0.6350448194491634

# %% [markdown]
# ### The Data is negatively skewed and has low kurtosis value
# ### Most of people have eduction Number of years of education 9 - 10

# %%
dfa = df_tmp[df_tmp.columns[0:13]]
obj_colum = dfa.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(obj_colum,1):
    plt.subplot(3,3,i)
    sns.countplot(data=dfa,y=col)
    plt.subplot(3,3,i+1)
    df_tmp[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Majority of the workclass is in Private Sector
# ### Also for education mojority of the people have HS graduation or some college degree

# %%
num_columns = dfa.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',fill=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#                age  educationno  capitalgain  capitalloss  hoursperweek
# skewness  0.532784    -0.310621    11.788871     4.517536      0.340536
# kurtosis -0.155931     0.635045   150.147899    19.376085      3.201287

# %% [markdown]
# ## __3 - SVM__

# %%
col = df1.columns

# %%
x_train = train[col[0:13]]
y_train = train[col[13]]
x_test = test[col[0:13]]
y_test = test[col[13]]

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_train = norm_func(x_train)
x_test =  norm_func(x_test)

# %% [markdown]
# ### 3.1 Linear

# %%
model_linear = SVC(kernel = "linear")
model_linear.fit(x_train,y_train)
pred_test_linear = model_linear.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_linear))
# Out:
# Accuracy: 0.8097609561752988

# %% [markdown]
# ### 3.2 Poly

# %%
model_poly = SVC(kernel = "poly")
model_poly.fit(x_train,y_train)
pred_test_poly = model_poly.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_poly))
# Out:
# Accuracy: 0.8435590969455511

# %% [markdown]
# ### 3.3 RBF

# %%
model_rbf = SVC(kernel = "rbf")
model_rbf.fit(x_train,y_train)
pred_test_rbf = model_rbf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_rbf))
# Out:
# Accuracy: 0.8432934926958832

# %% [markdown]
# ### 3.4 Sigmoid

# %%
model_sigmoid = SVC(kernel = "sigmoid")
model_sigmoid.fit(x_train,y_train)
pred_test_sigmoid = model_sigmoid.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_sigmoid))
# Out:
# Accuracy: 0.5768924302788845

# %% [markdown]
# ## __4 - Conclusion__

# %% [markdown]
# ## Poly Model gives the best accuracy
